# %% [markdown]
# ### **Import Needed Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, SGDRegressor, Lasso, Ridge

from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### **EDA**

# %% [markdown]
# **Read Data**

# %% [markdown]
# Data: https://www.kaggle.com/datasets/yashpaloswal/ann-car-sales-price-prediction

# %%
df = pd.read_csv('car_price.csv', encoding='ISO-8859-1')

# %% [markdown]
# **Explore the data**

# %%
df.sample(5)

# %% [markdown]
# **Get data info**

# %%
df.info()

# %% [markdown]
# #### **Data Preprocessing**

# %% [markdown]
# **Drop Unneeded Columns**

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country'], inplace=True)
df.head()

# %% [markdown]
# **Define Features X and Target y**

# %%
X = df.drop(columns=['car purchase amount'])
y = df[['car purchase amount']]

# %%
# Calculate the correlation matrix
corr_matrix = X.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Data Rescaling**

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# %% [markdown]
# **Data Splitting**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=True, random_state=42)

# %% [markdown]
# #### **Machine Learning Models**

# %% [markdown]
# **1. Linear Regression**

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# %% [markdown]
# **Model Accuracy**

# %%
lr_model.score(X_train, y_train)

# %% [markdown]
# **Get Prediction**

# %%
y_pred = lr_model.predict(X_test)

# %% [markdown]
# **Loss Function**

# %%
print(mean_squared_error(y_test, y_pred))

# %% [markdown]
# **Test Accuracy**

# %%
print(r2_score(y_test, y_pred))

# %% [markdown]
# **2. SGDRegressor**

# %%
sgd_regressor = SGDRegressor(max_iter=1000, tol=1e-5, alpha=0.0001, random_state=42)
sgd_regressor.fit(X_train, y_train)

# %% [markdown]
# **Model Accuracy**

# %%
sgd_regressor.score(X_train, y_train)

# %% [markdown]
# **Get Prediction**

# %%
y_pred = sgd_regressor.predict(X_test)

# %% [markdown]
# **Loss Function**

# %%
print(mean_squared_error(y_test, y_pred))

# %% [markdown]
# **Test Accuracy**

# %%
print(r2_score(y_test, y_pred))
